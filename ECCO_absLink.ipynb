# %%
import requests
from bs4 import BeautifulSoup as BS
import re
import pandas as pd
import bs4
import json

# %%
import requests

cookies = {
    '__RequestVerificationToken_L2NtU2VhcmNoYWJsZVByb2dyYW1tZQ2': 'grC7Lb_Ir072mk2brV1o5QDNFOvhx4KNwXmGuIhy0WWGw0_PMzGgzcTQN80iKjcyfwLafvyHALRIaZCb4zUiA7QdMmCZaCU1eUb2C5dnwhg1',
    '_ga': 'GA1.2.1774627581.1678098810',
    '_gid': 'GA1.2.2069338561.1678098810',
    '_gat_gtag_UA_xxxxxx_1': '1',
}

headers = {
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6ImFub255bW91cyIsIm5iZiI6MTY3ODA5ODkxMSwiZXhwIjoxNjc4MTg1MzExLCJpYXQiOjE2NzgwOTg5MTEsImlzcyI6ImVjY28taWJkIiwiYXVkIjoiY21zcGcifQ.fp9xSoeUwz54uxfammGjCv7VOWVieDpx6JplYWXoZi8',
    'Connection': 'keep-alive',
    # 'Cookie': '__RequestVerificationToken_L2NtU2VhcmNoYWJsZVByb2dyYW1tZQ2=grC7Lb_Ir072mk2brV1o5QDNFOvhx4KNwXmGuIhy0WWGw0_PMzGgzcTQN80iKjcyfwLafvyHALRIaZCb4zUiA7QdMmCZaCU1eUb2C5dnwhg1; _ga=GA1.2.1774627581.1678098810; _gid=GA1.2.2069338561.1678098810; _gat_gtag_UA_xxxxxx_1=1',
    'Referer': 'https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'covr-cmhost-customer': 'EC23',
    'covr-cmhost-function': 'normal',
    'sec-ch-ua': '"Chromium";v="110", "Not A(Brand";v="24", "Google Chrome";v="110"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'key': 'Tk9STUFM',
    '_': '1678098793656',
}

response = requests.get(
    'https://cm.ecco-ibd.eu/cmsearchableprogramme/conferencemanager/CM_W3_SearchableProgram/api/persionid/anonymous/getabstractdetails/conference/ec23/0001559390',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
df = pd.read_excel('ECCO_done.xlsx')
df
# Out:
#      source_id  manual_id                                      article_title  \
# 0          NaN        NaN  5th School for Clinical Trialists - Session 1 ...
# 1          NaN        NaN                                       Coffee Break
# 2        SCT01        NaN                             Welcome & Introduction
# 3        SCT02        NaN        Outcomes in IBD - What matters to patients?
# 4        SCT02        NaN        Outcomes in IBD - What matters to patients?
# ...        ...        ...                                                ...
# 1835      OP40        NaN  PRA023 Demonstrated Efficacy and Favorable Saf...
# 1836       NaN        NaN  Sequencing in IBD - Scientific Session 12  ECC...
# 1837     SCI30        NaN                                       ECCO Lecture
# 1838     SCI72        NaN                         Awards and closing remarks
# 1839       NaN        NaN                                      The ECCO Film
#
#                                                     url  \
# 0     https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 1     https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 2     https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 3     https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 4     https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# ...                                                 ...
# 1835  https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 1836  https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 1837  https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 1838  https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
# 1839  https://cm.ecco-ibd.eu/cmPortal/searchable/EC2...
#
#                                                 authors  \
# 0                                     Laurent Beaugerie
# 1                                                   NaN
# 2                                       Shaji Sebastian
# 3                              Wladyslawa Czuber-Dochan
# 4                                        Sameer Mannick
# ...                                                 ...
# 1835  B. Sands1,, L. Peyrin-Biroulet2,, S. Danese3,,...
# 1836  Laurent Peyrin-Biroulet; Britta Siegmund; Seba...
# 1837                                 Gillian Ann Carter
# 1838                                     Laurent Peyrin
# 1839                                                NaN
#
#                                      author_affiliation  \
# 0                                                France
# 1                                                   NaN
# 2                                        United Kingdom
# 3                                        United Kingdom
# 4                                        United Kingdom
# ...                                                 ...
# 1835  B. Sands1,, L. Peyrin-Biroulet2,, S. Danese3,,...
# 1836                           France; Germany; Germany
# 1837                                       South Africa
# 1838                                   Biroulet, France
# 1839                                                NaN
#
#                                           abstract_text                  date  \
# 0     Responsible Committee   ClinCom   Recommended ...  Wednesday  March 1st
# 1                                                   NaN  Wednesday  March 1st
# 2                                                   NaN  Wednesday  March 1st
# 3                                                   NaN  Wednesday  March 1st
# 4                                                   NaN  Wednesday  March 1st
# ...                                                 ...                   ...
# 1835  Background Background Tumor necrosis factor-li...   Saturday  March 4th
# 1836                                                NaN   Saturday  March 4th
# 1837                                                NaN   Saturday  March 4th
# 1838                                                NaN   Saturday  March 4th
# 1839                                                NaN   Saturday  March 4th
#
#      start_time end_time        location session_id news_type  \
# 0        08:00     10:00   Auditorium 10         S1   Session
# 1        09:30     10:00   Auditorium 10         S1  Abstract
# 2         08:00    10:00   Auditorium 10         S1  Abstract
# 3         08:00    10:00   Auditorium 10         S1  Abstract
# 4         08:00    10:00   Auditorium 10         S1  Abstract
# ...         ...      ...             ...        ...       ...
# 1835      10:50    12:20    Plenary Hall        S96  Abstract
# 1836     12:20     13:30    Plenary Hall        S97   Session
# 1837     12:20     12:50    Plenary Hall        S97  Abstract
# 1838     12:50     13:20    Plenary Hall        S97  Abstract
# 1839     13:20     13:30    Plenary Hall        S97  Abstract
#
#                                           session_title  \
# 0     5th School for Clinical Trialists - Session 1 ...
# 1     5th School for Clinical Trialists - Session 1 ...
# 2     5th School for Clinical Trialists - Session 1 ...
# 3     5th School for Clinical Trialists - Session 1 ...
# 4     5th School for Clinical Trialists - Session 1 ...
# ...                                                 ...
# 1835  Sequencing in IBD - Scientific Session 11  Fib...
# 1836  Sequencing in IBD - Scientific Session 12  ECC...
# 1837  Sequencing in IBD - Scientific Session 12  ECC...
# 1838  Sequencing in IBD - Scientific Session 12  ECC...
# 1839  Sequencing in IBD - Scientific Session 12  ECC...
#
#                session_type                           category  \
# 0     Educational Programme  5th School for Clinical Trialists
# 1     Educational Programme  5th School for Clinical Trialists
# 2     Educational Programme  5th School for Clinical Trialists
# 3     Educational Programme  5th School for Clinical Trialists
# 4     Educational Programme  5th School for Clinical Trialists
# ...                     ...                                ...
# 1835   Scientific Programme                                NaN
# 1836   Scientific Programme                                NaN
# 1837   Scientific Programme                                NaN
# 1838   Scientific Programme                                NaN
# 1839   Scientific Programme                                NaN
#
#                             sub_category  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1835  Keywords: 16 - Novel therapies \n
# 1836                                 NaN
# 1837                                 NaN
# 1838                                 NaN
# 1839                                 NaN
#
#                                              disclosure
# 0                                                   NaN
# 1                                                   NaN
# 2     Conflict of interest:Grant:\rTakeda, Tillots p...
# 3       Conflict of interest:Personal Fees:\rIBD Nordic
# 4                                                   NaN
# ...                                                 ...
# 1835  Conflict of interest:Grant:\rJanssen, Bristol ...
# 1836                                                NaN
# 1837                                                NaN
# 1838                                                NaN
# 1839                                                NaN
#
# [1840 rows x 18 columns]

# %%
all_data = response.json()

# %%
c = 1094
co = 0
for ur in df['url'][1094:]:
    if re.search('#!abstractdetails.*?', ur, flags=re.S):
        print(co)
        url = str(ur).split('/')[-1]
        response = requests.get(
            f'https://cm.ecco-ibd.eu/cmsearchableprogramme/conferencemanager/CM_W3_SearchableProgram/api/persionid/anonymous/getabstractdetails/conference/ec23/{url}',
            params=params,
            cookies=cookies,
            headers=headers,
        )
        print(ur)
        
        all_data = response.json()

        session_title = all_data['description']
        session_location = all_data['roomName']
        
        if all_data['presentations'][0]['start']:
            stime = all_data['presentations'][0]['start'].split('T')[1][:-3]
            etime = all_data['presentations'][0]['end'].split('T')[1][:-3]
        else:
            
            stime = all_data['start'].split('T')[1][:-3]
            etime = all_data['end'].split('T')[1][:-3]
            
#         session_type = all_data['sessionTypeDescription']
#         session_cate = all_data['trackDescription']
#         session_date = all_data['start'].split('T')[0]


#         src_id = all_data['presentations'][0]['catalogNumber'] + '; ' + all_data['presentations'][0]['presentationNumber']
#         src_id = re.sub('^; ', '', src_id)

#         art_title = all_data['presentations'][0]['subject']
#         art_authors = BS(all_data['presentations'][0]['formattedCoAuthors'], 'html.parser').text
#         art_absText = BS(all_data['presentations'][0]['abstractText'], 'html.parser').text

#         art_absText = ''
#         abs_flag = False
#         for i in BS(all_data['presentations'][0]['abstractText'], 'html.parser').find_all():
#             if re.search('Background', i.text, flags=re.S):
#                 abs_flag = True
#             if abs_flag:
#                 art_absText += i.text + ' '

#         keywords = 'Keywords: '
#         for i in all_data['presentations'][0]['abstractKeywords']:
#             keywords += i['keyword'] + ' \n '

#         if keywords == 'Keywords: ':
#             keywords = ''        

#         disclosure = BS(all_data['presentations'][0]['disclosure'], 'html.parser').text

#         if len(art_authors) < 1:
#             auth = all_data['presentations'][0]['personFirstName'] + ' ' + all_data['presentations'][0]['personLastName']
#             aff = all_data['presentations'][0]['personCountry']
#         else:
#             aff = re.search('\d{1,3}[A-Z].*', art_authors, flags=re.S).group()
#             auth = re.sub(aff, '', art_authors, flags=re.S)



#         print(f'src id :- {src_id}')
#         print(f'tit :- {art_title}')
#         print(f'auth :- {auth}')
#         print(f'aff :- {aff}')
#         print(f'time :- {session_Stime} {session_Etime}')
#         print(f'key :- {keywords}')
#         print(f'diss :- {disclosure}')
#         print(f'textt :- {art_absText}')
        print(stime)
        print(etime)
        print('========'*18)
        
#         df.iat[c, df.columns.get_loc('source_id')] = src_id
#         df.iat[c, df.columns.get_loc('article_title')] = art_title
#         df.iat[c, df.columns.get_loc('authors')] = auth
#         df.iat[c, df.columns.get_loc('author_affiliation')] = aff
#         df.iat[c, df.columns.get_loc('abstract_text')] = art_absText
        df.iat[c, df.columns.get_loc('start_time')] = stime
        df.iat[c, df.columns.get_loc('end_time')] = etime
#         df.iat[c, df.columns.get_loc('sub_category')] = keywords
#         df.iat[c, df.columns.get_loc('disclosure')] = disclosure
        
        co += 1
    c += 1
# Out:
# 0
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574730
# 12:30
# 13:30
# ================================================================================================================================================
# 1
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562240
# 12:30
# 13:30
# ================================================================================================================================================
# 2
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562230
# 12:30
# 13:30
# ================================================================================================================================================
# 3
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562220
# 12:30
# 13:30
# ================================================================================================================================================
# 4
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562210
# 12:30
# 13:30
# ================================================================================================================================================
# 5
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562200
# 12:30
# 13:30
# ================================================================================================================================================
# 6
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562190
# 12:30
# 13:30
# ================================================================================================================================================
# 7
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562180
# 12:30
# 13:30
# ================================================================================================================================================
# 8
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562170
# 12:30
# 13:30
# ================================================================================================================================================
# 9
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562160
# 12:30
# 13:30
# ================================================================================================================================================
# 10
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562150
# 12:30
# 13:30
# ================================================================================================================================================
# 11
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562140
# 12:30
# 13:30
# ================================================================================================================================================
# 12
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562130
# 12:30
# 13:30
# ================================================================================================================================================
# 13
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562120
# 12:30
# 13:30
# ================================================================================================================================================
# 14
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562110
# 12:30
# 13:30
# ================================================================================================================================================
# 15
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562100
# 12:30
# 13:30
# ================================================================================================================================================
# 16
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562090
# 12:30
# 13:30
# ================================================================================================================================================
# 17
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562080
# 12:30
# 13:30
# ================================================================================================================================================
# 18
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562070
# 12:30
# 13:30
# ================================================================================================================================================
# 19
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562060
# 12:30
# 13:30
# ================================================================================================================================================
# 20
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562050
# 12:30
# 13:30
# ================================================================================================================================================
# 21
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562040
# 12:30
# 13:30
# ================================================================================================================================================
# 22
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562030
# 12:30
# 13:30
# ================================================================================================================================================
# 23
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562020
# 12:30
# 13:30
# ================================================================================================================================================
# 24
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562010
# 12:30
# 13:30
# ================================================================================================================================================
# 25
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001562000
# 12:30
# 13:30
# ================================================================================================================================================
# 26
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561990
# 12:30
# 13:30
# ================================================================================================================================================
# 27
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561980
# 12:30
# 13:30
# ================================================================================================================================================
# 28
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561970
# 12:30
# 13:30
# ================================================================================================================================================
# 29
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561960
# 12:30
# 13:30
# ================================================================================================================================================
# 30
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561950
# 12:30
# 13:30
# ================================================================================================================================================
# 31
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561940
# 12:30
# 13:30
# ================================================================================================================================================
# 32
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561930
# 12:30
# 13:30
# ================================================================================================================================================
# 33
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561920
# 12:30
# 13:30
# ================================================================================================================================================
# 34
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561910
# 12:30
# 13:30
# ================================================================================================================================================
# 35
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561900
# 12:30
# 13:30
# ================================================================================================================================================
# 36
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561890
# 12:30
# 13:30
# ================================================================================================================================================
# 37
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561880
# 12:30
# 13:30
# ================================================================================================================================================
# 38
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561870
# 12:30
# 13:30
# ================================================================================================================================================
# 39
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561860
# 12:30
# 13:30
# ================================================================================================================================================
# 40
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561850
# 12:30
# 13:30
# ================================================================================================================================================
# 41
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561840
# 12:30
# 13:30
# ================================================================================================================================================
# 42
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561830
# 12:30
# 13:30
# ================================================================================================================================================
# 43
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561820
# 12:30
# 13:30
# ================================================================================================================================================
# 44
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561810
# 12:30
# 13:30
# ================================================================================================================================================
# 45
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561800
# 12:30
# 13:30
# ================================================================================================================================================
# 46
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561790
# 12:30
# 13:30
# ================================================================================================================================================
# 47
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561780
# 12:30
# 13:30
# ================================================================================================================================================
# 48
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561770
# 12:30
# 13:30
# ================================================================================================================================================
# 49
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561760
# 12:30
# 13:30
# ================================================================================================================================================
# 50
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561750
# 12:30
# 13:30
# ================================================================================================================================================
# 51
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561740
# 12:30
# 13:30
# ================================================================================================================================================
# 52
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561730
# 12:30
# 13:30
# ================================================================================================================================================
# 53
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561720
# 12:30
# 13:30
# ================================================================================================================================================
# 54
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561710
# 12:30
# 13:30
# ================================================================================================================================================
# 55
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561700
# 12:30
# 13:30
# ================================================================================================================================================
# 56
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561690
# 12:30
# 13:30
# ================================================================================================================================================
# 57
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561680
# 12:30
# 13:30
# ================================================================================================================================================
# 58
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561670
# 12:30
# 13:30
# ================================================================================================================================================
# 59
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561660
# 12:30
# 13:30
# ================================================================================================================================================
# 60
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561650
# 12:30
# 13:30
# ================================================================================================================================================
# 61
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561640
# 12:30
# 13:30
# ================================================================================================================================================
# 62
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561630
# 12:30
# 13:30
# ================================================================================================================================================
# 63
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561620
# 12:30
# 13:30
# ================================================================================================================================================
# 64
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561610
# 12:30
# 13:30
# ================================================================================================================================================
# 65
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561600
# 12:30
# 13:30
# ================================================================================================================================================
# 66
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561590
# 12:30
# 13:30
# ================================================================================================================================================
# 67
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561580
# 12:30
# 13:30
# ================================================================================================================================================
# 68
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561570
# 12:30
# 13:30
# ================================================================================================================================================
# 69
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561560
# 12:30
# 13:30
# ================================================================================================================================================
# 70
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561550
# 12:30
# 13:30
# ================================================================================================================================================
# 71
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561540
# 12:30
# 13:30
# ================================================================================================================================================
# 72
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561530
# 12:30
# 13:30
# ================================================================================================================================================
# 73
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561520
# 12:30
# 13:30
# ================================================================================================================================================
# 74
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561510
# 12:30
# 13:30
# ================================================================================================================================================
# 75
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561500
# 12:30
# 13:30
# ================================================================================================================================================
# 76
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561490
# 12:30
# 13:30
# ================================================================================================================================================
# 77
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561480
# 12:30
# 13:30
# ================================================================================================================================================
# 78
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561470
# 12:30
# 13:30
# ================================================================================================================================================
# 79
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561460
# 12:30
# 13:30
# ================================================================================================================================================
# 80
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561450
# 12:30
# 13:30
# ================================================================================================================================================
# 81
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561440
# 12:30
# 13:30
# ================================================================================================================================================
# 82
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561430
# 12:30
# 13:30
# ================================================================================================================================================
# 83
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561420
# 12:30
# 13:30
# ================================================================================================================================================
# 84
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001561410
# 12:30
# 13:30
# ================================================================================================================================================
# 85
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574720
# 12:30
# 13:30
# ================================================================================================================================================
# 86
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574710
# 12:30
# 13:30
# ================================================================================================================================================
# 87
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574700
# 12:30
# 13:30
# ================================================================================================================================================
# 88
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574690
# 12:30
# 13:30
# ================================================================================================================================================
# 89
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574680
# 12:30
# 13:30
# ================================================================================================================================================
# 90
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574670
# 12:30
# 13:30
# ================================================================================================================================================
# 91
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574660
# 12:30
# 13:30
# ================================================================================================================================================
# 92
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574650
# 12:30
# 13:30
# ================================================================================================================================================
# 93
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574640
# 12:30
# 13:30
# ================================================================================================================================================
# 94
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574630
# 12:30
# 13:30
# ================================================================================================================================================
# 95
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574620
# 12:30
# 13:30
# ================================================================================================================================================
# 96
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574610
# 12:30
# 13:30
# ================================================================================================================================================
# 97
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574600
# 12:30
# 13:30
# ================================================================================================================================================
# 98
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574590
# 12:30
# 13:30
# ================================================================================================================================================
# 99
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574580
# 12:30
# 13:30
# ================================================================================================================================================
# 100
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574570
# 12:30
# 13:30
# ================================================================================================================================================
# 101
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574560
# 12:30
# 13:30
# ================================================================================================================================================
# 102
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574550
# 12:30
# 13:30
# ================================================================================================================================================
# 103
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574540
# 12:30
# 13:30
# ================================================================================================================================================
# 104
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574530
# 12:30
# 13:30
# ================================================================================================================================================
# 105
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574520
# 12:30
# 13:30
# ================================================================================================================================================
# 106
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574510
# 12:30
# 13:30
# ================================================================================================================================================
# 107
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574500
# 12:30
# 13:30
# ================================================================================================================================================
# 108
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574490
# 12:30
# 13:30
# ================================================================================================================================================
# 109
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574480
# 12:30
# 13:30
# ================================================================================================================================================
# 110
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574470
# 12:30
# 13:30
# ================================================================================================================================================
# 111
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574460
# 12:30
# 13:30
# ================================================================================================================================================
# 112
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574450
# 12:30
# 13:30
# ================================================================================================================================================
# 113
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574440
# 12:30
# 13:30
# ================================================================================================================================================
# 114
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574430
# 12:30
# 13:30
# ================================================================================================================================================
# 115
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574420
# 12:30
# 13:30
# ================================================================================================================================================
# 116
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574410
# 12:30
# 13:30
# ================================================================================================================================================
# 117
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574400
# 12:30
# 13:30
# ================================================================================================================================================
# 118
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574390
# 12:30
# 13:30
# ================================================================================================================================================
# 119
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574380
# 12:30
# 13:30
# ================================================================================================================================================
# 120
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574370
# 12:30
# 13:30
# ================================================================================================================================================
# 121
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574360
# 12:30
# 13:30
# ================================================================================================================================================
# 122
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574350
# 12:30
# 13:30
# ================================================================================================================================================
# 123
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574340
# 12:30
# 13:30
# ================================================================================================================================================
# 124
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574330
# 12:30
# 13:30
# ================================================================================================================================================
# 125
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574320
# 12:30
# 13:30
# ================================================================================================================================================
# 126
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574310
# 12:30
# 13:30
# ================================================================================================================================================
# 127
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574300
# 12:30
# 13:30
# ================================================================================================================================================
# 128
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574290
# 12:30
# 13:30
# ================================================================================================================================================
# 129
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574280
# 12:30
# 13:30
# ================================================================================================================================================
# 130
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574270
# 12:30
# 13:30
# ================================================================================================================================================
# 131
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574260
# 12:30
# 13:30
# ================================================================================================================================================
# 132
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574250
# 12:30
# 13:30
# ================================================================================================================================================
# 133
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574240
# 12:30
# 13:30
# ================================================================================================================================================
# 134
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574230
# 12:30
# 13:30
# ================================================================================================================================================
# 135
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574220
# 12:30
# 13:30
# ================================================================================================================================================
# 136
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574210
# 12:30
# 13:30
# ================================================================================================================================================
# 137
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574200
# 12:30
# 13:30
# ================================================================================================================================================
# 138
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574190
# 12:30
# 13:30
# ================================================================================================================================================
# 139
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574180
# 12:30
# 13:30
# ================================================================================================================================================
# 140
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574170
# 12:30
# 13:30
# ================================================================================================================================================
# 141
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574160
# 12:30
# 13:30
# ================================================================================================================================================
# 142
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574150
# 12:30
# 13:30
# ================================================================================================================================================
# 143
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574140
# 12:30
# 13:30
# ================================================================================================================================================
# 144
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574130
# 12:30
# 13:30
# ================================================================================================================================================
# 145
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574120
# 12:30
# 13:30
# ================================================================================================================================================
# 146
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574110
# 12:30
# 13:30
# ================================================================================================================================================
# 147
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574100
# 12:30
# 13:30
# ================================================================================================================================================
# 148
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574090
# 12:30
# 13:30
# ================================================================================================================================================
# 149
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574080
# 12:30
# 13:30
# ================================================================================================================================================
# 150
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574070
# 12:30
# 13:30
# ================================================================================================================================================
# 151
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574060
# 12:30
# 13:30
# ================================================================================================================================================
# 152
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574040
# 12:30
# 13:30
# ================================================================================================================================================
# 153
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574030
# 12:30
# 13:30
# ================================================================================================================================================
# 154
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574020
# 12:30
# 13:30
# ================================================================================================================================================
# 155
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574010
# 12:30
# 13:30
# ================================================================================================================================================
# 156
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574000
# 12:30
# 13:30
# ================================================================================================================================================
# 157
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573990
# 12:30
# 13:30
# ================================================================================================================================================
# 158
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573980
# 12:30
# 13:30
# ================================================================================================================================================
# 159
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573970
# 12:30
# 13:30
# ================================================================================================================================================
# 160
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573960
# 12:30
# 13:30
# ================================================================================================================================================
# 161
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573950
# 12:30
# 13:30
# ================================================================================================================================================
# 162
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573940
# 12:30
# 13:30
# ================================================================================================================================================
# 163
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573930
# 12:30
# 13:30
# ================================================================================================================================================
# 164
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573920
# 12:30
# 13:30
# ================================================================================================================================================
# 165
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573910
# 12:30
# 13:30
# ================================================================================================================================================
# 166
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573900
# 12:30
# 13:30
# ================================================================================================================================================
# 167
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573890
# 12:30
# 13:30
# ================================================================================================================================================
# 168
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573880
# 12:30
# 13:30
# ================================================================================================================================================
# 169
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573870
# 12:30
# 13:30
# ================================================================================================================================================
# 170
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573860
# 12:30
# 13:30
# ================================================================================================================================================
# 171
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573850
# 12:30
# 13:30
# ================================================================================================================================================
# 172
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573840
# 12:30
# 13:30
# ================================================================================================================================================
# 173
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573830
# 12:30
# 13:30
# ================================================================================================================================================
# 174
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573820
# 12:30
# 13:30
# ================================================================================================================================================
# 175
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573810
# 12:30
# 13:30
# ================================================================================================================================================
# 176
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573800
# 12:30
# 13:30
# ================================================================================================================================================
# 177
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573790
# 12:30
# 13:30
# ================================================================================================================================================
# 178
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573780
# 12:30
# 13:30
# ================================================================================================================================================
# 179
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573770
# 12:30
# 13:30
# ================================================================================================================================================
# 180
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573760
# 12:30
# 13:30
# ================================================================================================================================================
# 181
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573750
# 12:30
# 13:30
# ================================================================================================================================================
# 182
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573740
# 12:30
# 13:30
# ================================================================================================================================================
# 183
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573730
# 12:30
# 13:30
# ================================================================================================================================================
# 184
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573720
# 12:30
# 13:30
# ================================================================================================================================================
# 185
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573710
# 12:30
# 13:30
# ================================================================================================================================================
# 186
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573700
# 12:30
# 13:30
# ================================================================================================================================================
# 187
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573690
# 12:30
# 13:30
# ================================================================================================================================================
# 188
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573680
# 12:30
# 13:30
# ================================================================================================================================================
# 189
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573670
# 12:30
# 13:30
# ================================================================================================================================================
# 190
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573660
# 12:30
# 13:30
# ================================================================================================================================================
# 191
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001573650
# 12:30
# 13:30
# ...
# 12:30
# 13:30
# ================================================================================================================================================
# 653
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574880
# 12:30
# 13:30
# ================================================================================================================================================
# 654
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574870
# 12:30
# 13:30
# ================================================================================================================================================
# 655
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574860
# 12:30
# 13:30
# ================================================================================================================================================
# 656
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574850
# 12:30
# 13:30
# ================================================================================================================================================
# 657
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574840
# 12:30
# 13:30
# ================================================================================================================================================
# 658
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574830
# 12:30
# 13:30
# ================================================================================================================================================
# 659
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574820
# 12:30
# 13:30
# ================================================================================================================================================
# 660
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574810
# 12:30
# 13:30
# ================================================================================================================================================
# 661
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574800
# 12:30
# 13:30
# ================================================================================================================================================
# 662
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574790
# 12:30
# 13:30
# ================================================================================================================================================
# 663
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001574780
# 12:30
# 13:30
# ================================================================================================================================================
# 664
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559820
# 17:25
# 17:31
# ================================================================================================================================================
# 665
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559810
# 17:31
# 17:37
# ================================================================================================================================================
# 666
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559800
# 17:37
# 17:43
# ================================================================================================================================================
# 667
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559790
# 17:43
# 17:49
# ================================================================================================================================================
# 668
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559780
# 17:49
# 17:55
# ================================================================================================================================================
# 669
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559770
# 17:55
# 18:01
# ================================================================================================================================================
# 670
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559760
# 18:01
# 18:07
# ================================================================================================================================================
# 671
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559750
# 18:07
# 18:13
# ================================================================================================================================================
# 672
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560210
# 18:13
# 18:19
# ================================================================================================================================================
# 673
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559920
# 17:25
# 17:31
# ================================================================================================================================================
# 674
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559910
# 17:31
# 17:37
# ================================================================================================================================================
# 675
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559900
# 17:37
# 17:43
# ================================================================================================================================================
# 676
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559890
# 17:43
# 17:49
# ================================================================================================================================================
# 677
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559880
# 17:49
# 17:55
# ================================================================================================================================================
# 678
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559870
# 17:55
# 18:01
# ================================================================================================================================================
# 679
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559860
# 18:01
# 18:07
# ================================================================================================================================================
# 680
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559850
# 18:07
# 18:13
# ================================================================================================================================================
# 681
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559840
# 18:13
# 18:19
# ================================================================================================================================================
# 682
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559990
# 17:25
# 17:31
# ================================================================================================================================================
# 683
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559980
# 17:31
# 17:37
# ================================================================================================================================================
# 684
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559970
# 17:37
# 17:43
# ================================================================================================================================================
# 685
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559960
# 17:43
# 17:49
# ================================================================================================================================================
# 686
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559950
# 17:49
# 17:55
# ================================================================================================================================================
# 687
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559940
# 17:55
# 18:01
# ================================================================================================================================================
# 688
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559930
# 18:01
# 18:07
# ================================================================================================================================================
# 689
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560000
# 18:07
# 18:13
# ================================================================================================================================================
# 690
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560010
# 18:13
# 18:19
# ================================================================================================================================================
# 691
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560040
# 17:25
# 17:31
# ================================================================================================================================================
# 692
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560030
# 17:31
# 17:37
# ================================================================================================================================================
# 693
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560020
# 17:37
# 17:43
# ================================================================================================================================================
# 694
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560070
# 17:43
# 17:49
# ================================================================================================================================================
# 695
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560060
# 17:49
# 17:55
# ================================================================================================================================================
# 696
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560050
# 17:55
# 18:01
# ================================================================================================================================================
# 697
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560100
# 18:01
# 18:07
# ================================================================================================================================================
# 698
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560090
# 18:07
# 18:13
# ================================================================================================================================================
# 699
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560080
# 18:13
# 18:19
# ================================================================================================================================================
# 700
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560180
# 17:25
# 17:31
# ================================================================================================================================================
# 701
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560170
# 17:31
# 17:37
# ================================================================================================================================================
# 702
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560150
# 17:43
# 17:49
# ================================================================================================================================================
# 703
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560140
# 17:49
# 17:55
# ================================================================================================================================================
# 704
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560190
# 17:55
# 18:01
# ================================================================================================================================================
# 705
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560130
# 18:01
# 18:07
# ================================================================================================================================================
# 706
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560120
# 18:07
# 18:13
# ================================================================================================================================================
# 707
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001560110
# 18:13
# 18:19
# ================================================================================================================================================
# 708
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559260
# 08:50
# 09:00
# ================================================================================================================================================
# 709
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559270
# 09:20
# 09:30
# ================================================================================================================================================
# 710
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559250
# 09:50
# 10:00
# ================================================================================================================================================
# 711
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559240
# 10:00
# 10:10
# ================================================================================================================================================
# 712
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559230
# 10:10
# 10:20
# ================================================================================================================================================
# 713
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559280
# 11:10
# 11:20
# ================================================================================================================================================
# 714
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559290
# 11:40
# 11:50
# ================================================================================================================================================
# 715
# https://cm.ecco-ibd.eu/cmPortal/searchable/EC23/config/normal#!abstractdetails/0001559300
# 11:50
# 12:00
# ================================================================================================================================================

# %%
df.to_excel('ECCO_final.xlsx', index=False)
